# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv(r'C:\Users\Ghalamkarian\PycharmProjects\pythonProject3\cigrette.csv')

# %%
data1.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   40         165          70       84.0             1.2              1.2
# 1   80         160          60       93.0             1.0              1.0
# 2   60         170          70       86.5             0.6              0.7
# 3   40         160          50       67.0             0.3              0.4
# 4   40         170          75       89.4             1.0              0.9
#
#    systolic  fasting blood sugar  Cholesterol  triglyceride  HDL  LDL  \
# 0       130                  107          200           186   49  115
# 1       144                   93          172           158   35  104
# 2       117                   92          161           173   39   88
# 3       116                   91          213            47   75  128
# 4       132                   79          170           100   39  123
#
#    hemoglobin  cardiovascular_risk_score  blood_pressure_variation        bmi  \
# ...

# %%
data1.dtypes
# Out:
# age                              int64
# height(cm)                       int64
# weight(kg)                       int64
# waist(cm)                      float64
# eyesight(left)                 float64
# eyesight(right)                float64
# systolic                         int64
# fasting blood sugar              int64
# Cholesterol                      int64
# triglyceride                     int64
# HDL                              int64
# LDL                              int64
# hemoglobin                     float64
# cardiovascular_risk_score      float64
# blood_pressure_variation         int64
# bmi                            float64
# cardiovascular_health_score    float64
# dtype: object

# %%
data1.astype('float')
# Out:
#        age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0     40.0       165.0        70.0       84.0             1.2
# 1     80.0       160.0        60.0       93.0             1.0
# 2     60.0       170.0        70.0       86.5             0.6
# 3     40.0       160.0        50.0       67.0             0.3
# 4     40.0       170.0        75.0       89.4             1.0
# ...    ...         ...         ...        ...             ...
# 1032  45.0       165.0        75.0       87.0             1.0
# 1033  20.0       180.0        70.0       76.0             0.9
# 1034  45.0       165.0        70.0       85.0             1.5
# 1035  50.0       165.0        60.0       84.0             0.7
# 1036  60.0       155.0        50.0       69.0             0.7
#
#       eyesight(right)  systolic  fasting blood sugar  Cholesterol  \
# 0                 1.2     130.0                107.0        200.0
# 1                 1.0     144.0                 93.0        172.0
# ...

# %%
data1.shape
# Out:
# (1037, 17)

# %%
data1.size
# Out:
# 17629

# %%
data1.isnull().sum()
# Out:
# age                            0
# height(cm)                     0
# weight(kg)                     0
# waist(cm)                      0
# eyesight(left)                 0
# eyesight(right)                0
# systolic                       0
# fasting blood sugar            0
# Cholesterol                    0
# triglyceride                   0
# HDL                            0
# LDL                            0
# hemoglobin                     0
# cardiovascular_risk_score      0
# blood_pressure_variation       0
# bmi                            0
# cardiovascular_health_score    0
# dtype: int64

# %%
x1=data1[['age','height(cm)','waist(cm)','eyesight(left)','eyesight(right)','systolic','HDL','LDL','hemoglobin','bmi']]
print(x1[:5])
# Out:
#    age  height(cm)  waist(cm)  eyesight(left)  eyesight(right)  systolic  HDL  \
# 0   40         165       84.0             1.2              1.2       130   49
# 1   80         160       93.0             1.0              1.0       144   35
# 2   60         170       86.5             0.6              0.7       117   39
# 3   40         160       67.0             0.3              0.4       116   75
# 4   40         170       89.4             1.0              0.9       132   39
#
#    LDL  hemoglobin        bmi
# 0  115        14.2  25.711662
# 1  104        13.0  23.437500
# 2   88        15.4  24.221453
# 3  128        14.5  19.531250
# 4  123        16.5  25.951557

# %%
from sklearn.preprocessing import MinMaxScaler
xo=x1.values
scaler=MinMaxScaler()
normaldata=scaler.fit_transform(xo)
normaldata[0:5]
# Out:
# array([[0.33333333, 0.55555556, 0.48717949, 0.1122449 , 0.1122449 ,
#         0.5       , 0.24050633, 0.55555556, 0.58035714, 0.48206205],
#        [1.        , 0.44444444, 0.65201465, 0.09183673, 0.09183673,
#         0.675     , 0.06329114, 0.4973545 , 0.47321429, 0.38257398],
#        [0.66666667, 0.66666667, 0.53296703, 0.05102041, 0.06122449,
#         0.3375    , 0.11392405, 0.41269841, 0.6875    , 0.41686969],
#        [0.33333333, 0.44444444, 0.17582418, 0.02040816, 0.03061224,
#         0.325     , 0.56962025, 0.62433862, 0.60714286, 0.21168675],
#        [0.33333333, 0.66666667, 0.58608059, 0.09183673, 0.08163265,
#         0.525     , 0.11392405, 0.5978836 , 0.78571429, 0.49255676]])

# %%
from sklearn.metrics.pairwise import euclidean_distances
dis=euclidean_distances(normaldata, normaldata)
print(dis)
# Out:
# [[0.         0.75603492 0.4587722  ... 0.38027861 0.33870691 0.72180821]
#  [0.75603492 0.         0.58991559 ... 0.8624811  0.67358679 0.90658413]
#  [0.4587722  0.58991559 0.         ... 0.47980513 0.55162821 0.79922654]
#  ...
#  [0.38027861 0.8624811  0.47980513 ... 0.         0.48775996 0.79707156]
#  [0.33870691 0.67358679 0.55162821 ... 0.48775996 0.         0.58076916]
#  [0.72180821 0.90658413 0.79922654 ... 0.79707156 0.58076916 0.        ]]

# %%
from sklearn.cluster import AgglomerativeClustering

agglom=AgglomerativeClustering(linkage='complete')
rr=agglom.fit(normaldata)

# %%
u=agglom.labels_p
# Out:
# [1 0 1 ... 1 1 0]

# %%
data1['cluster']=agglom.labels_

# %%
data1.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   40         165          70       84.0             1.2              1.2
# 1   80         160          60       93.0             1.0              1.0
# 2   60         170          70       86.5             0.6              0.7
# 3   40         160          50       67.0             0.3              0.4
# 4   40         170          75       89.4             1.0              0.9
#
#    systolic  fasting blood sugar  Cholesterol  triglyceride  HDL  LDL  \
# 0       130                  107          200           186   49  115
# 1       144                   93          172           158   35  104
# 2       117                   92          161           173   39   88
# 3       116                   91          213            47   75  128
# 4       132                   79          170           100   39  123
#
#    hemoglobin  cardiovascular_risk_score  blood_pressure_variation        bmi  \
# ...

# %%
data1.value_counts(data1['cluster'])
# Out:
# cluster
# 1    822
# 0    215
# Name: count, dtype: int64

# %%
#compere=data1.groupby(['cluster','Cholesterol'])['weight(kg)','fasting blood sugar','hemoglobin','bmi'].mean()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
z=linkage(normaldata,'complete')

dendrogram(z)

plt.show()
